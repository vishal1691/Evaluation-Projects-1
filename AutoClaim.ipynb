# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
df_auto = pd.read_csv("Auto_Insurance_Claims_amount.csv")
df_auto
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0     BU79786      US         KS    Kansas    276.351928       No     Basic
# 1     QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2     AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3     WW63253      US         MO  Missouri    764.586183       No     Basic
# 4     HB64268      US         KS    Kansas    281.369258       No     Basic
# ...       ...     ...        ...       ...           ...      ...       ...
# 9129  LA72316      US         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824      US         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
# ...

# %%
df_auto.columns
# Out:
# Index(['Customer', 'Country', 'State Code', 'State', 'Claim Amount',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Claim Reason',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
df_auto.shape
# Out:
# (9134, 26)

# %% [markdown]
# # EDA

# %%
df_auto.isnull().sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df_auto['Country']=label_encoder.fit_transform(df_auto['Country'])

# %%
df_auto['Country'].unique()
# Out:
# array([0])

# %%
df_auto
# Out:
#      Customer  Country State Code     State  Claim Amount Response  Coverage  \
# 0     BU79786        0         KS    Kansas    276.351928       No     Basic
# 1     QZ44356        0         NE  Nebraska    697.953590       No  Extended
# 2     AI49188        0         OK  Oklahoma   1288.743165       No   Premium
# 3     WW63253        0         MO  Missouri    764.586183       No     Basic
# 4     HB64268        0         KS    Kansas    281.369258       No     Basic
# ...       ...      ...        ...       ...           ...      ...       ...
# 9129  LA72316        0         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824        0         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365        0         MO  Missouri    816.389043       No  Extended
# 9132  UP19263        0         MO  Missouri    752.444244       No  Extended
# 9133  Y167826        0         MO  Missouri    261.183687       No  Extended
#
# ...

# %%
df_auto['State Code']=label_encoder.fit_transform(df_auto['State Code'])

# %%
df_auto['State Code'].unique()
# Out:
# array([1, 3, 4, 2, 0])

# %%
df_auto
# Out:
#      Customer  Country  State Code     State  Claim Amount Response  Coverage  \
# 0     BU79786        0           1    Kansas    276.351928       No     Basic
# 1     QZ44356        0           3  Nebraska    697.953590       No  Extended
# 2     AI49188        0           4  Oklahoma   1288.743165       No   Premium
# 3     WW63253        0           2  Missouri    764.586183       No     Basic
# 4     HB64268        0           1    Kansas    281.369258       No     Basic
# ...       ...      ...         ...       ...           ...      ...       ...
# 9129  LA72316        0           2  Missouri   2340.598798       No     Basic
# 9130  PK87824        0           2  Missouri    309.651122      Yes  Extended
# 9131  TD14365        0           2  Missouri    816.389043       No  Extended
# 9132  UP19263        0           2  Missouri    752.444244       No  Extended
# 9133  Y167826        0           2  Missouri    261.183687       No  Extended
#
# ...

# %%
df_auto['State']=label_encoder.fit_transform(df_auto['State'])

# %%
df_auto['State'].unique()
# Out:
# array([1, 3, 4, 2, 0])

# %%
df_auto
# Out:
#      Customer  Country  State Code  State  Claim Amount Response  Coverage  \
# 0     BU79786        0           1      1    276.351928       No     Basic
# 1     QZ44356        0           3      3    697.953590       No  Extended
# 2     AI49188        0           4      4   1288.743165       No   Premium
# 3     WW63253        0           2      2    764.586183       No     Basic
# 4     HB64268        0           1      1    281.369258       No     Basic
# ...       ...      ...         ...    ...           ...      ...       ...
# 9129  LA72316        0           2      2   2340.598798       No     Basic
# 9130  PK87824        0           2      2    309.651122      Yes  Extended
# 9131  TD14365        0           2      2    816.389043       No  Extended
# 9132  UP19263        0           2      2    752.444244       No  Extended
# 9133  Y167826        0           2      2    261.183687       No  Extended
#
#      Education Effective To Date EmploymentStatus  ...  \
# ...

# %%
df_auto.dtypes
# Out:
# Customer                          object
# Country                            int64
# State Code                         int64
# State                              int64
# Claim Amount                     float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Claim Reason                      object
# Sales Channel                     object
# ...

# %%
df_auto['Response']=label_encoder.fit_transform(df_auto['Response'])

# %%
df_auto['Response'].unique()
# Out:
# array([0, 1])

# %%
df_auto['Coverage']=label_encoder.fit_transform(df_auto['Coverage'])

# %%
df_auto['Education']=label_encoder.fit_transform(df_auto['Education'])

# %%
df_auto['EmploymentStatus']=label_encoder.fit_transform(df_auto['EmploymentStatus'])

# %%
df_auto['Claim Reason']=label_encoder.fit_transform(df_auto['Claim Reason'])

# %%
df_auto['Sales Channel']=label_encoder.fit_transform(df_auto['Sales Channel'])

# %%
df_auto['Vehicle Class']=label_encoder.fit_transform(df_auto['Vehicle Class'])

# %%
df_auto['Vehicle Size']=label_encoder.fit_transform(df_auto['Vehicle Size'])

# %%
df_auto.dtypes
# Out:
# Customer                          object
# Country                            int64
# State Code                         int64
# State                              int64
# Claim Amount                     float64
# Response                           int64
# Coverage                           int64
# Education                          int64
# Effective To Date                 object
# EmploymentStatus                   int64
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Claim Reason                       int64
# Sales Channel                      int64
# ...

# %%
df_auto
# Out:
#      Customer  Country  State Code  State  Claim Amount  Response  Coverage  \
# 0     BU79786        0           1      1    276.351928         0         0
# 1     QZ44356        0           3      3    697.953590         0         1
# 2     AI49188        0           4      4   1288.743165         0         2
# 3     WW63253        0           2      2    764.586183         0         0
# 4     HB64268        0           1      1    281.369258         0         0
# ...       ...      ...         ...    ...           ...       ...       ...
# 9129  LA72316        0           2      2   2340.598798         0         0
# 9130  PK87824        0           2      2    309.651122         1         1
# 9131  TD14365        0           2      2    816.389043         0         1
# 9132  UP19263        0           2      2    752.444244         0         1
# 9133  Y167826        0           2      2    261.183687         0         1
#
# ...

# %%
df_auto['Policy Type']=label_encoder.fit_transform(df_auto['Policy Type'])

# %%
df_auto['Policy']=label_encoder.fit_transform(df_auto['Policy'])

# %%
df_auto
# Out:
#      Customer  Country  State Code  State  Claim Amount  Response  Coverage  \
# 0     BU79786        0           1      1    276.351928         0         0
# 1     QZ44356        0           3      3    697.953590         0         1
# 2     AI49188        0           4      4   1288.743165         0         2
# 3     WW63253        0           2      2    764.586183         0         0
# 4     HB64268        0           1      1    281.369258         0         0
# ...       ...      ...         ...    ...           ...       ...       ...
# 9129  LA72316        0           2      2   2340.598798         0         0
# 9130  PK87824        0           2      2    309.651122         1         1
# 9131  TD14365        0           2      2    816.389043         0         1
# 9132  UP19263        0           2      2    752.444244         0         1
# 9133  Y167826        0           2      2    261.183687         0         1
#
# ...

# %%
df_auto['Marital Status']=label_encoder.fit_transform(df_auto['Marital Status'])
df_auto['Location Code']=label_encoder.fit_transform(df_auto['Location Code'])

# %%
df_auto['Gender']=label_encoder.fit_transform(df_auto['Gender'])

# %%
df_auto
# Out:
#      Customer  Country  State Code  State  Claim Amount  Response  Coverage  \
# 0     BU79786        0           1      1    276.351928         0         0
# 1     QZ44356        0           3      3    697.953590         0         1
# 2     AI49188        0           4      4   1288.743165         0         2
# 3     WW63253        0           2      2    764.586183         0         0
# 4     HB64268        0           1      1    281.369258         0         0
# ...       ...      ...         ...    ...           ...       ...       ...
# 9129  LA72316        0           2      2   2340.598798         0         0
# 9130  PK87824        0           2      2    309.651122         1         1
# 9131  TD14365        0           2      2    816.389043         0         1
# 9132  UP19263        0           2      2    752.444244         0         1
# 9133  Y167826        0           2      2    261.183687         0         1
#
# ...

# %%
df_auto.dtypes
# Out:
# Customer                          object
# Country                            int64
# State Code                         int64
# State                              int64
# Claim Amount                     float64
# Response                           int64
# Coverage                           int64
# Education                          int64
# Effective To Date                 object
# EmploymentStatus                   int64
# Gender                             int64
# Income                             int64
# Location Code                      int64
# Marital Status                     int64
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                        int64
# Policy                             int64
# Claim Reason                       int64
# Sales Channel                      int64
# ...

# %%
df_auto['Customer']=label_encoder.fit_transform(df_auto['Customer'])

# %%
df_auto
# Out:
#       Customer  Country  State Code  State  Claim Amount  Response  Coverage  \
# 0          600        0           1      1    276.351928         0         0
# 1         5946        0           3      3    697.953590         0         1
# 2           96        0           4      4   1288.743165         0         2
# 3         8016        0           2      2    764.586183         0         0
# 4         2488        0           1      1    281.369258         0         0
# ...        ...      ...         ...    ...           ...       ...       ...
# 9129      3857        0           2      2   2340.598798         0         0
# 9130      5390        0           2      2    309.651122         1         1
# 9131      6688        0           2      2    816.389043         0         1
# 9132      7214        0           2      2    752.444244         0         1
# 9133      8434        0           2      2    261.183687         0         1
#
# ...

# %%
df_auto['Month']= df_auto['Effective To Date'].str.split('/').str[0]
df_auto['Date']= df_auto['Effective To Date'].str.split('/').str[1]
df_auto['Year']= df_auto['Effective To Date'].str.split('/').str[2]

# %%
df_auto
# Out:
#       Customer  Country  State Code  State  Claim Amount  Response  Coverage  \
# 0          600        0           1      1    276.351928         0         0
# 1         5946        0           3      3    697.953590         0         1
# 2           96        0           4      4   1288.743165         0         2
# 3         8016        0           2      2    764.586183         0         0
# 4         2488        0           1      1    281.369258         0         0
# ...        ...      ...         ...    ...           ...       ...       ...
# 9129      3857        0           2      2   2340.598798         0         0
# 9130      5390        0           2      2    309.651122         1         1
# 9131      6688        0           2      2    816.389043         0         1
# 9132      7214        0           2      2    752.444244         0         1
# 9133      8434        0           2      2    261.183687         0         1
#
# ...

# %%
df_auto['Month']= df_auto['Month'].astype(int)
df_auto['Date']= df_auto['Date'].astype(int)
df_auto['Year']= df_auto['Year'].astype(int)

# %%
df_auto.dtypes
# Out:
# Customer                           int64
# Country                            int64
# State Code                         int64
# State                              int64
# Claim Amount                     float64
# Response                           int64
# Coverage                           int64
# Education                          int64
# Effective To Date                 object
# EmploymentStatus                   int64
# Gender                             int64
# Income                             int64
# Location Code                      int64
# Marital Status                     int64
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                        int64
# Policy                             int64
# Claim Reason                       int64
# Sales Channel                      int64
# ...

# %%
df_auto=df_auto.drop(['Effective To Date'],axis=1)

# %%
df_auto
# Out:
#       Customer  Country  State Code  State  Claim Amount  Response  Coverage  \
# 0          600        0           1      1    276.351928         0         0
# 1         5946        0           3      3    697.953590         0         1
# 2           96        0           4      4   1288.743165         0         2
# 3         8016        0           2      2    764.586183         0         0
# 4         2488        0           1      1    281.369258         0         0
# ...        ...      ...         ...    ...           ...       ...       ...
# 9129      3857        0           2      2   2340.598798         0         0
# 9130      5390        0           2      2    309.651122         1         1
# 9131      6688        0           2      2    816.389043         0         1
# 9132      7214        0           2      2    752.444244         0         1
# 9133      8434        0           2      2    261.183687         0         1
#
# ...

# %%
df_auto.dtypes
# Out:
# Customer                           int64
# Country                            int64
# State Code                         int64
# State                              int64
# Claim Amount                     float64
# Response                           int64
# Coverage                           int64
# Education                          int64
# EmploymentStatus                   int64
# Gender                             int64
# Income                             int64
# Location Code                      int64
# Marital Status                     int64
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                        int64
# Policy                             int64
# Claim Reason                       int64
# Sales Channel                      int64
# Total Claim Amount               float64
# ...

# %%
df_auto.describe()
# Out:
#           Customer  Country   State Code        State  Claim Amount  \
# count  9134.000000   9134.0  9134.000000  9134.000000   9134.000000
# mean   4566.500000      0.0     1.722684     1.722684    800.494047
# std    2636.903013      0.0     1.312397     1.312397    687.096761
# min       0.000000      0.0     0.000000     0.000000    189.800768
# 25%    2283.250000      0.0     0.000000     0.000000    399.425179
# 50%    4566.500000      0.0     2.000000     2.000000    578.018220
# 75%    6849.750000      0.0     3.000000     3.000000    896.216704
# max    9133.000000      0.0     4.000000     4.000000   8332.538119
#
#           Response     Coverage    Education  EmploymentStatus       Gender  \
# count  9134.000000  9134.000000  9134.000000       9134.000000  9134.000000
# mean      0.143201     0.480622     1.554084          1.825706     0.490037
# std       0.350297     0.655817     1.381978          1.347793     0.499928
# ...

# %%
df_x=df_auto.drop(columns=["Total Claim Amount"])
y=pd.DataFrame(df_auto["Total Claim Amount"])

# %%
df_x
# Out:
#       Customer  Country  State Code  State  Claim Amount  Response  Coverage  \
# 0          600        0           1      1    276.351928         0         0
# 1         5946        0           3      3    697.953590         0         1
# 2           96        0           4      4   1288.743165         0         2
# 3         8016        0           2      2    764.586183         0         0
# 4         2488        0           1      1    281.369258         0         0
# ...        ...      ...         ...    ...           ...       ...       ...
# 9129      3857        0           2      2   2340.598798         0         0
# 9130      5390        0           2      2    309.651122         1         1
# 9131      6688        0           2      2    816.389043         0         1
# 9132      7214        0           2      2    752.444244         0         1
# 9133      8434        0           2      2    261.183687         0         1
#
# ...

# %%
y
# Out:
#       Total Claim Amount
# 0             384.811147
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4             138.130879
# ...                  ...
# 9129          198.234764
# 9130          379.200000
# 9131          790.784983
# 9132          691.200000
# 9133          369.600000
#
# [9134 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x = sc.fit_transform(df_x)
x = pd.DataFrame(x,columns=df_x.columns)

# %%
x
# Out:
#       Customer  Country  State Code     State  Claim Amount  Response  \
# 0    -1.504309      0.0   -0.550690 -0.550690     -0.762878 -0.408822
# 1     0.523180      0.0    0.973322  0.973322     -0.149245 -0.408822
# 2    -1.695453      0.0    1.735328  1.735328      0.710636 -0.408822
# 3     1.308235      0.0    0.211316  0.211316     -0.052263 -0.408822
# 4    -0.788278      0.0   -0.550690 -0.550690     -0.755575 -0.408822
# ...        ...      ...         ...       ...           ...       ...
# 9129 -0.269080      0.0    0.211316  0.211316      2.241590 -0.408822
# 9130  0.312315      0.0    0.211316  0.211316     -0.714411  2.446054
# 9131  0.804586      0.0    0.211316  0.211316      0.023135 -0.408822
# 9132  1.004074      0.0    0.211316  0.211316     -0.069935 -0.408822
# 9133  1.466763      0.0    0.211316  0.211316     -0.784955 -0.408822
#
#       Coverage  Education  EmploymentStatus    Gender  ...  \
# 0    -0.732899  -1.124597         -0.612669 -0.980269  ...
# ...

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr = r2_score(y_test,y_pred)
        print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state 
    print("max r2 score corresponding to",final_r_state," is ",max_r_score)
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.6009841949930637
# r2 score corresponding to random state:  43 is:  0.5766969349845856
# r2 score corresponding to random state:  44 is:  0.6093160466074492
# r2 score corresponding to random state:  45 is:  0.6131043981039903
# r2 score corresponding to random state:  46 is:  0.5954475051936374
# r2 score corresponding to random state:  47 is:  0.6207354877648804
# r2 score corresponding to random state:  48 is:  0.6381793299834739
# r2 score corresponding to random state:  49 is:  0.6187234247657698
# r2 score corresponding to random state:  50 is:  0.5796851716362064
# r2 score corresponding to random state:  51 is:  0.6156134854735538
# r2 score corresponding to random state:  52 is:  0.6226207358278237
# r2 score corresponding to random state:  53 is:  0.6155010496870038
# r2 score corresponding to random state:  54 is:  0.6265236642067769
# r2 score corresponding to random state:  55 is:  0.6387005099242744
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=10,scoring="r2").mean()
# Out:
# 0.6043608492116184

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr = GridSearchCV(knr, neighbors, cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 8}

# %%
knr=KNeighborsRegressor(n_neighbors=8)
r_state=maxr2_score(knr,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.6461145757952848
# r2 score corresponding to random state:  43 is:  0.6446360928371506
# r2 score corresponding to random state:  44 is:  0.646586877606169
# r2 score corresponding to random state:  45 is:  0.6563828727853059
# r2 score corresponding to random state:  46 is:  0.6229352808235551
# r2 score corresponding to random state:  47 is:  0.6535220023945667
# r2 score corresponding to random state:  48 is:  0.6773064482258474
# r2 score corresponding to random state:  49 is:  0.6494555088016731
# r2 score corresponding to random state:  50 is:  0.6309083474498873
# r2 score corresponding to random state:  51 is:  0.657318623944357
# r2 score corresponding to random state:  52 is:  0.6484821469142596
# r2 score corresponding to random state:  53 is:  0.6389526932014382
# r2 score corresponding to random state:  54 is:  0.6498563598684746
# r2 score corresponding to random state:  55 is:  0.6440895973772972
# ...

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2score for Linear Regression: ",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Linear Regression: ",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
print()
print("Mean r2score for KNN Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for KNN Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for Linear Regression:  0.6044649706069757
# Standard deviation in r2 score for Linear Regression:  0.019144563380985732
#
# Mean r2score for KNN Regression:  0.6503212346767813
# Standard deviation in r2 score for KNN Regression:  0.013484914706966108

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
glsr = GridSearchCV(lsreg, parameters, cv=10)
glsr.fit(x,y)
glsr.best_params_
# Out:
# {'alpha': 1}

# %%
lsreg=Lasso(alpha=1)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.6003650793180785
# r2 score corresponding to random state:  43 is:  0.5773373344895409
# r2 score corresponding to random state:  44 is:  0.6092062390485475
# r2 score corresponding to random state:  45 is:  0.6133870964512096
# r2 score corresponding to random state:  46 is:  0.5959356075021769
# r2 score corresponding to random state:  47 is:  0.6205535999985554
# r2 score corresponding to random state:  48 is:  0.6384198190531329
# r2 score corresponding to random state:  49 is:  0.6196627220069602
# r2 score corresponding to random state:  50 is:  0.5807665301541531
# r2 score corresponding to random state:  51 is:  0.6153818732453232
# r2 score corresponding to random state:  52 is:  0.6220474713989905
# r2 score corresponding to random state:  53 is:  0.6163032319816649
# r2 score corresponding to random state:  54 is:  0.6256719671296215
# r2 score corresponding to random state:  55 is:  0.638448649058533
# ...

# %%
print("Mean r2score for Lasso Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Lasso Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for Lasso Regression:  0.6047485710813003
# Standard deviation in r2 score for Lasso Regression:  0.018564571946491377

# %%
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
ggbr = GridSearchCV(gbr, parameters, cv=5)
ggbr.fit(x,y)
ggbr.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 500}

# %%
gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=500)
print("Mean r2score for gradient boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Gradient Boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for gradient boosting Regression:  0.8325225379569632
# Standard deviation in r2 score for Gradient Boosting Regression:  0.007991143647769509

# %%
r_state=maxr2_score(gbr,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.8215649322763542
# r2 score corresponding to random state:  43 is:  0.8272305513774847
# r2 score corresponding to random state:  44 is:  0.8335571025580695
# r2 score corresponding to random state:  45 is:  0.8445505925221193
# r2 score corresponding to random state:  46 is:  0.8142218268097948
# r2 score corresponding to random state:  47 is:  0.8315298918794882
# r2 score corresponding to random state:  48 is:  0.8399760325457614
# r2 score corresponding to random state:  49 is:  0.8342287680503265
# r2 score corresponding to random state:  50 is:  0.829066540809761
# r2 score corresponding to random state:  51 is:  0.8429355970516672
# r2 score corresponding to random state:  52 is:  0.8464900629090819
# r2 score corresponding to random state:  53 is:  0.8429634461049214
# r2 score corresponding to random state:  54 is:  0.8367791158032194
# r2 score corresponding to random state:  55 is:  0.8235067535299695
# ...

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lreg,lsreg,DecisionTreeRegressor()]}
gada = GridSearchCV(ada_reg, parameters, cv=5)
gada.fit(x,y)
gada.best_params_

# %%
ada_reg=AdaBoostRegressor(learning_rate=0.1,n_estimators=100)
print("Mean r2score for Ada boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Ada Boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for Ada boosting Regression:  0.7183978887594026
# Standard deviation in r2 score for Ada Boosting Regression:  0.01577823090788943

# %%
r_state=maxr2_score(ada_reg,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.7111054731592343
# r2 score corresponding to random state:  43 is:  0.7179871438412562
# r2 score corresponding to random state:  44 is:  0.715414707605857
# r2 score corresponding to random state:  45 is:  0.7283126361217038
# r2 score corresponding to random state:  46 is:  0.7150863840366564
# r2 score corresponding to random state:  47 is:  0.7248379493915913
# r2 score corresponding to random state:  48 is:  0.7447126871724892
# r2 score corresponding to random state:  49 is:  0.7190390610899299
# r2 score corresponding to random state:  50 is:  0.7044790814742279
# r2 score corresponding to random state:  51 is:  0.7380588971718194
# r2 score corresponding to random state:  52 is:  0.7490679159153806
# r2 score corresponding to random state:  53 is:  0.7340806328080502
# r2 score corresponding to random state:  54 is:  0.7421617135027363
# r2 score corresponding to random state:  55 is:  0.7332527623153
# ...

# %% [markdown]
# # Model Selection

# %% [raw]
# I choose GradientBoostingRegressor Model as my preferred model as it performs better on the above dataset.
