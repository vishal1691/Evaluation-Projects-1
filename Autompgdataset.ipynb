# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
df_auto = pd.read_csv("auto-mpg.csv")
df_auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df_auto.shape
# Out:
# (398, 9)

# %%
df_auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df_auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
df_auto.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
sns.heatmap(df_auto.isnull())

# %%
df_auto['horsepower'].fillna(df_auto['horsepower'].mode()[0], inplace=True)

# %%
df_auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df_auto['horsepower']=label_encoder.fit_transform(df_auto['horsepower'])

# %%
df_auto['horsepower'].unique()
# Out:
# array([15, 33, 27, 22, 40, 45, 44, 46, 38, 35, 32, 89, 91, 79, 82, 48, 81,
#        84,  8, 41, 43, 39, 93,  0,  3, 36, 29, 37,  6, 67, 80, 65, 70, 60,
#        64, 55, 74, 53, 42, 30,  7, 86, 24, 19, 31, 34, 88,  4, 47, 50, 69,
#        85, 12, 62, 77, 72, 51, 56, 87, 25, 14, 90, 66, 92,  9, 52, 75, 73,
#        11, 28,  1,  5, 63, 54, 26, 83, 58, 49, 61, 21,  2, 13, 17, 20, 18,
#        23, 71, 57, 16, 78, 59, 68, 10, 76])

# %%
df_auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0          15    3504          12.0
# 1    15.0          8         350.0          33    3693          11.5
# 2    18.0          8         318.0          27    3436          11.0
# 3    16.0          8         304.0          27    3433          12.0
# 4    17.0          8         302.0          22    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          80    2790          15.6
# 394  44.0          4          97.0          51    2130          24.6
# 395  32.0          4         135.0          78    2295          11.6
# 396  28.0          4         120.0          73    2625          18.6
# 397  31.0          4         119.0          76    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df_auto['car name']=label_encoder.fit_transform(df_auto['car name'])

# %%
df_auto['car name'].unique()
# Out:
# array([ 49,  36, 231,  14, 161, 141,  54, 223, 241,   1, 101, 215,  57,
#         30, 274, 220,   8, 150,  95, 282, 211,  16, 258,  22,   7, 133,
#         68, 112, 163,  65, 271, 156, 232, 162,  10, 242, 116, 129, 250,
#          9,  64, 243, 151, 187, 208, 210, 123, 267,  76, 286, 218, 272,
#        105, 293,  63, 158,   2, 192,  31, 203,  75, 183,  11,  48, 143,
#        233, 295, 283, 212, 253, 157,  85, 279, 104, 268,  25,  55, 142,
#        109, 193,  44, 148, 222,  74,  29,   0, 235,  62, 292, 128, 219,
#        207, 263,  87, 174, 188, 121,  59, 244, 124, 209,  17, 294, 113,
#        260, 276, 204,  61,  92,  50, 234,  27, 110,  21, 284,  88, 103,
#        122, 167, 261, 127, 236, 194,  42, 224,  24,  41, 221,  34,  60,
#        154, 266, 240, 287,  12, 296, 171, 125,  40, 254, 108,  51,  66,
#        302, 100, 145, 252,  13,  91, 297, 239, 186,  39,  67, 132, 111,
#        165,  32, 256, 216,  94, 202, 117, 189,  53,  35, 238, 144, 245,
#         58,  70, 160, 288, 251, 269, 155, 107, 262,  89,  23, 181, 289,
#        139, 180,  93, 201, 114, 195, 249, 135, 136, 237,   3,  28, 196,
#         98,   4,  33, 140, 115,  84, 118, 265, 230, 206,  77,  19, 298,
#        259, 214, 291, 166, 247, 197, 137,   6,  99, 149, 190, 120,  56,
#         73, 304, 173, 106,  15, 184,  38, 225, 228,  79, 126,  37,  52,
#        205, 248, 270,  82, 134,  18, 273, 175,  86, 176, 303, 300,  20,
#        185, 170, 257, 281,  81, 182, 280, 152, 164, 229,  97, 277, 217,
#        169,  80, 278, 177, 226, 131, 130, 285, 255, 172,  78, 213, 299,
#        275,  90, 200, 146,  72,  45,  47,  46, 246,  96, 138,   5, 290,
#        179, 178, 227, 191, 198, 168,  83,  26, 199,  71, 147, 264, 102,
#         43, 153, 301, 119, 159,  69])

# %%
df_auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0          15    3504          12.0
# 1    15.0          8         350.0          33    3693          11.5
# 2    18.0          8         318.0          27    3436          11.0
# 3    16.0          8         304.0          27    3433          12.0
# 4    17.0          8         302.0          22    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          80    2790          15.6
# 394  44.0          4          97.0          51    2130          24.6
# 395  32.0          4         135.0          78    2295          11.6
# 396  28.0          4         120.0          73    2625          18.6
# 397  31.0          4         119.0          76    2720          19.4
#
#      model year  origin  car name
# 0            70       1        49
# 1            70       1        36
# 2            70       1       231
# 3            70       1        14
# 4            70       1       161
# ..          ...     ...       ...
# 393          82       1       153
# 394          82       2       301
# 395          82       1       119
# 396          82       1       159
# 397          82       1        69
#
# [398 rows x 9 columns]

# %%
df_auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name          int64
# dtype: object

# %%
for col in df_auto.columns:
    if df_auto.skew().loc[col]>0.55:
        df_auto[col]=np.log1p(df_auto[col])

# %%
df_auto.skew()
# Out:
# mpg             0.457066
# cylinders       0.526922
# displacement    0.228886
# horsepower     -0.316618
# weight          0.531063
# acceleration    0.278777
# model year      0.011535
# origin          0.796540
# car name        0.018665
# dtype: float64

# %%
from scipy.stats import zscore
z_score=abs(zscore(df_auto))
print(df_auto.shape)
df_auto_final=df_auto.loc[(z_score<3).all(axis=1)]
print(df_auto_final.shape)
# Out:
# (398, 9)
# (396, 9)

# %%
sns.lineplot(x="mpg",y="model year",data=df_auto)
plt.show()

# %%
sns.lineplot(x="mpg",y="horsepower",data=df_auto)
plt.show()

# %%
df_x=df_auto_final.drop(columns=["mpg"])
y=pd.DataFrame(df_auto_final["mpg"])

# %%
df_x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0            8      5.730100          15    3504          12.0          70
# 1            8      5.860786          33    3693          11.5          70
# 2            8      5.765191          27    3436          11.0          70
# 3            8      5.720312          27    3433          12.0          70
# 4            8      5.713733          22    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 392          4      5.023881          84    2950          17.3          82
# 393          4      4.948760          80    2790          15.6          82
# 395          4      4.912655          78    2295          11.6          82
# 396          4      4.795791          73    2625          18.6          82
# 397          4      4.787492          76    2720          19.4          82
#
#        origin  car name
# 0    0.693147        49
# 1    0.693147        36
# 2    0.693147       231
# 3    0.693147        14
# 4    0.693147       161
# ..        ...       ...
# 392  0.693147        43
# 393  0.693147       153
# 395  0.693147       119
# 396  0.693147       159
# 397  0.693147        69
#
# [396 rows x 8 columns]

# %%
y
# Out:
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 392  27.0
# 393  27.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [396 rows x 1 columns]

# %%
df_auto_final.skew()
# Out:
# mpg             0.445176
# cylinders       0.518701
# displacement    0.221856
# horsepower     -0.312546
# weight          0.528711
# acceleration    0.154848
# model year      0.017950
# origin          0.806283
# car name        0.023663
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x = sc.fit_transform(df_x)
x = pd.DataFrame(x,columns=df_x.columns)

# %%
df_auto_final.skew()
# Out:
# mpg             0.445176
# cylinders       0.518701
# displacement    0.221856
# horsepower     -0.312546
# weight          0.528711
# acceleration    0.154848
# model year      0.017950
# origin          0.806283
# car name        0.023663
# dtype: float64

# %%
x
# Out:
#      cylinders  displacement  horsepower    weight  acceleration  model year  \
# 0     1.492875      1.133295   -1.201672  0.628268     -1.312496   -1.623956
# 1     1.492875      1.380822   -0.596933  0.851465     -1.498826   -1.623956
# 2     1.492875      1.199760   -0.798513  0.547964     -1.685156   -1.623956
# 3     1.492875      1.114756   -0.798513  0.544421     -1.312496   -1.623956
# 4     1.492875      1.102295   -0.966496  0.563316     -1.871486   -1.623956
# ..         ...           ...         ...       ...           ...         ...
# 391  -0.860074     -0.204320    1.116493 -0.025972      0.662600    1.630805
# 392  -0.860074     -0.346603    0.982106 -0.214922      0.029079    1.630805
# 393  -0.860074     -0.414987    0.914913 -0.799486     -1.461560    1.630805
# 394  -0.860074     -0.636334    0.746930 -0.409777      1.147058    1.630805
# 395  -0.860074     -0.652053    0.847720 -0.297587      1.445186    1.630805
#
#        origin  car name
# 0   -0.731161 -1.109653
# 1   -0.731161 -1.255354
# 2   -0.731161  0.930159
# 3   -0.731161 -1.501924
# 4   -0.731161  0.145616
# ..        ...       ...
# 391 -0.731161 -1.176899
# 392 -0.731161  0.055954
# 393 -0.731161 -0.325110
# 394 -0.731161  0.123200
# 395 -0.731161 -0.885498
#
# [396 rows x 8 columns]

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr = r2_score(y_test,y_pred)
        print("r2 score corresponding to random state: ",r_state,"is: ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state 
    print("max r2 score corresponding to",final_r_state," is ",max_r_score)
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.7952566759796107
# r2 score corresponding to random state:  43 is:  0.7919628291244052
# r2 score corresponding to random state:  44 is:  0.8200111315659605
# r2 score corresponding to random state:  45 is:  0.8236577616355705
# r2 score corresponding to random state:  46 is:  0.7930551732648243
# r2 score corresponding to random state:  47 is:  0.8181909930419201
# r2 score corresponding to random state:  48 is:  0.8176986179952463
# r2 score corresponding to random state:  49 is:  0.8458421299267728
# r2 score corresponding to random state:  50 is:  0.8213101937366148
# r2 score corresponding to random state:  51 is:  0.847439294756522
# r2 score corresponding to random state:  52 is:  0.8469644618558188
# r2 score corresponding to random state:  53 is:  0.8627156747069625
# r2 score corresponding to random state:  54 is:  0.8059817606902281
# r2 score corresponding to random state:  55 is:  0.8481679173735825
# r2 score corresponding to random state:  56 is:  0.837519637848268
# r2 score corresponding to random state:  57 is:  0.7691846551888797
# r2 score corresponding to random state:  58 is:  0.8627861099810128
# r2 score corresponding to random state:  59 is:  0.8041414528816666
# r2 score corresponding to random state:  60 is:  0.7268897948739566
# r2 score corresponding to random state:  61 is:  0.8489769788546708
# r2 score corresponding to random state:  62 is:  0.8168330883930993
# r2 score corresponding to random state:  63 is:  0.8256643497850692
# r2 score corresponding to random state:  64 is:  0.8266672642482247
# r2 score corresponding to random state:  65 is:  0.8245830001509517
# r2 score corresponding to random state:  66 is:  0.7928936867999187
# r2 score corresponding to random state:  67 is:  0.7958375882740298
# r2 score corresponding to random state:  68 is:  0.8327800537618509
# r2 score corresponding to random state:  69 is:  0.8253820621589366
# r2 score corresponding to random state:  70 is:  0.8103305830970233
# r2 score corresponding to random state:  71 is:  0.8380842565675864
# r2 score corresponding to random state:  72 is:  0.8488742290603228
# r2 score corresponding to random state:  73 is:  0.8162960914559143
# r2 score corresponding to random state:  74 is:  0.8032185927055946
# r2 score corresponding to random state:  75 is:  0.777269571126751
# r2 score corresponding to random state:  76 is:  0.7805016887004204
# r2 score corresponding to random state:  77 is:  0.7969093826148914
# r2 score corresponding to random state:  78 is:  0.8419820974695076
# r2 score corresponding to random state:  79 is:  0.8094633899792492
# r2 score corresponding to random state:  80 is:  0.8151357166453791
# r2 score corresponding to random state:  81 is:  0.8280074427568757
# r2 score corresponding to random state:  82 is:  0.7831191501940175
# r2 score corresponding to random state:  83 is:  0.8206994858817241
# r2 score corresponding to random state:  84 is:  0.7752954304510713
# r2 score corresponding to random state:  85 is:  0.8082647003622566
# r2 score corresponding to random state:  86 is:  0.8490148809778341
# r2 score corresponding to random state:  87 is:  0.8078602089642368
# r2 score corresponding to random state:  88 is:  0.8012325991797262
# r2 score corresponding to random state:  89 is:  0.7999266246514638
# r2 score corresponding to random state:  90 is:  0.8470300969991607
# r2 score corresponding to random state:  91 is:  0.8264751087763539
# r2 score corresponding to random state:  92 is:  0.8433912233243208
# r2 score corresponding to random state:  93 is:  0.8427953532637322
# r2 score corresponding to random state:  94 is:  0.8645153100075693
# r2 score corresponding to random state:  95 is:  0.7727480273559677
# r2 score corresponding to random state:  96 is:  0.7710285626558018
# r2 score corresponding to random state:  97 is:  0.7910750175761215
# r2 score corresponding to random state:  98 is:  0.7830631640112253
# r2 score corresponding to random state:  99 is:  0.7663603889677391
# max r2 score corresponding to 94  is  0.8645153100075693

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=10,scoring="r2").mean()
# Out:
# 0.6350161236522518

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr = GridSearchCV(knr, neighbors, cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 5}

# %%
knr=KNeighborsRegressor(n_neighbors=5)
r_state=maxr2_score(knr,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.8215370096461189
# r2 score corresponding to random state:  43 is:  0.8020920349123254
# r2 score corresponding to random state:  44 is:  0.8327080992742399
# r2 score corresponding to random state:  45 is:  0.7916669129197612
# r2 score corresponding to random state:  46 is:  0.8201031513988338
# r2 score corresponding to random state:  47 is:  0.8389040986391159
# r2 score corresponding to random state:  48 is:  0.8327780670800776
# r2 score corresponding to random state:  49 is:  0.8518257990459726
# r2 score corresponding to random state:  50 is:  0.8033381772003132
# r2 score corresponding to random state:  51 is:  0.8676702658756094
# r2 score corresponding to random state:  52 is:  0.8456599834943443
# r2 score corresponding to random state:  53 is:  0.8785298359906863
# r2 score corresponding to random state:  54 is:  0.8368040369465962
# r2 score corresponding to random state:  55 is:  0.8690760295509861
# r2 score corresponding to random state:  56 is:  0.9017216422152886
# r2 score corresponding to random state:  57 is:  0.8284427603817315
# r2 score corresponding to random state:  58 is:  0.85874126248551
# r2 score corresponding to random state:  59 is:  0.7885454433096414
# r2 score corresponding to random state:  60 is:  0.8029313756824203
# r2 score corresponding to random state:  61 is:  0.8023944115169894
# r2 score corresponding to random state:  62 is:  0.8535880787139422
# r2 score corresponding to random state:  63 is:  0.8341906952877624
# r2 score corresponding to random state:  64 is:  0.8224084339218835
# r2 score corresponding to random state:  65 is:  0.8267024474132958
# r2 score corresponding to random state:  66 is:  0.8445899598789699
# r2 score corresponding to random state:  67 is:  0.7409413673552012
# r2 score corresponding to random state:  68 is:  0.8054388268485314
# r2 score corresponding to random state:  69 is:  0.862811609716346
# r2 score corresponding to random state:  70 is:  0.8556412628051866
# r2 score corresponding to random state:  71 is:  0.8390635014184709
# r2 score corresponding to random state:  72 is:  0.8956710207963908
# r2 score corresponding to random state:  73 is:  0.8472014698183259
# r2 score corresponding to random state:  74 is:  0.8604442964990856
# r2 score corresponding to random state:  75 is:  0.7926345816888475
# r2 score corresponding to random state:  76 is:  0.8562089843633032
# r2 score corresponding to random state:  77 is:  0.796936477635336
# r2 score corresponding to random state:  78 is:  0.8678075887880303
# r2 score corresponding to random state:  79 is:  0.8511094281425714
# r2 score corresponding to random state:  80 is:  0.743692323029574
# r2 score corresponding to random state:  81 is:  0.8679123936512225
# r2 score corresponding to random state:  82 is:  0.8085896326817191
# r2 score corresponding to random state:  83 is:  0.810611694911307
# r2 score corresponding to random state:  84 is:  0.8402441202080437
# r2 score corresponding to random state:  85 is:  0.827661396787954
# r2 score corresponding to random state:  86 is:  0.8551797690588019
# r2 score corresponding to random state:  87 is:  0.8059876600442067
# r2 score corresponding to random state:  88 is:  0.7833117402695431
# r2 score corresponding to random state:  89 is:  0.8071164444104945
# r2 score corresponding to random state:  90 is:  0.879375668977378
# r2 score corresponding to random state:  91 is:  0.8128661813880019
# r2 score corresponding to random state:  92 is:  0.8535854496142687
# r2 score corresponding to random state:  93 is:  0.9061373673749774
# r2 score corresponding to random state:  94 is:  0.871426257950938
# r2 score corresponding to random state:  95 is:  0.8046603472160054
# r2 score corresponding to random state:  96 is:  0.7625554319799872
# r2 score corresponding to random state:  97 is:  0.8175811685029548
# r2 score corresponding to random state:  98 is:  0.8047170584321031
# r2 score corresponding to random state:  99 is:  0.8424037834826714
# max r2 score corresponding to 93  is  0.9061373673749774

# %%
from sklearn.model_selection import cross_val_score
print("Mean r2score for Linear Regression: ",cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Linear Regression: ",cross_val_score(lreg,x,y,cv=5,scoring="r2").std())
print()
print("Mean r2score for KNN Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for KNN Regression: ",cross_val_score(knr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for Linear Regression:  0.5975155498465635
# Standard deviation in r2 score for Linear Regression:  0.22479887270375856
#
# Mean r2score for KNN Regression:  0.6845224871408973
# Standard deviation in r2 score for KNN Regression:  0.21853768807492252

# %%
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
glsr = GridSearchCV(lsreg, parameters, cv=10)
glsr.fit(x,y)
glsr.best_params_
# Out:
# {'alpha': 0.1}

# %%
lsreg=Lasso(alpha=0.1)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.7922105879657839
# r2 score corresponding to random state:  43 is:  0.7881635944394922
# r2 score corresponding to random state:  44 is:  0.8280181350557251
# r2 score corresponding to random state:  45 is:  0.8160084808994833
# r2 score corresponding to random state:  46 is:  0.7924830806173384
# r2 score corresponding to random state:  47 is:  0.81083971556447
# r2 score corresponding to random state:  48 is:  0.8054856338080179
# r2 score corresponding to random state:  49 is:  0.8537855736485058
# r2 score corresponding to random state:  50 is:  0.8121447923081532
# r2 score corresponding to random state:  51 is:  0.8409320068939496
# r2 score corresponding to random state:  52 is:  0.8536510961325335
# r2 score corresponding to random state:  53 is:  0.8654224567326201
# r2 score corresponding to random state:  54 is:  0.7930721225637145
# r2 score corresponding to random state:  55 is:  0.8470956057817651
# r2 score corresponding to random state:  56 is:  0.831288984800717
# r2 score corresponding to random state:  57 is:  0.7735032478666781
# r2 score corresponding to random state:  58 is:  0.8543796367987853
# r2 score corresponding to random state:  59 is:  0.8042707285490709
# r2 score corresponding to random state:  60 is:  0.737572703199953
# r2 score corresponding to random state:  61 is:  0.8521002489872479
# r2 score corresponding to random state:  62 is:  0.8094436885193779
# r2 score corresponding to random state:  63 is:  0.8196316038227203
# r2 score corresponding to random state:  64 is:  0.815108903441828
# r2 score corresponding to random state:  65 is:  0.8138505674906711
# r2 score corresponding to random state:  66 is:  0.7902323757991786
# r2 score corresponding to random state:  67 is:  0.7960938809400537
# r2 score corresponding to random state:  68 is:  0.8292180821573706
# r2 score corresponding to random state:  69 is:  0.8155730816701546
# r2 score corresponding to random state:  70 is:  0.8133221952763564
# r2 score corresponding to random state:  71 is:  0.8447991210164771
# r2 score corresponding to random state:  72 is:  0.8445806711522215
# r2 score corresponding to random state:  73 is:  0.8109078600505305
# r2 score corresponding to random state:  74 is:  0.795309376471177
# r2 score corresponding to random state:  75 is:  0.7786233756109913
# r2 score corresponding to random state:  76 is:  0.782146426621811
# r2 score corresponding to random state:  77 is:  0.7859739798838075
# r2 score corresponding to random state:  78 is:  0.8336196668394009
# r2 score corresponding to random state:  79 is:  0.80167334956243
# r2 score corresponding to random state:  80 is:  0.8160087250027639
# r2 score corresponding to random state:  81 is:  0.816616927856379
# r2 score corresponding to random state:  82 is:  0.7841432294027342
# r2 score corresponding to random state:  83 is:  0.8103136869906197
# r2 score corresponding to random state:  84 is:  0.7715809007786403
# r2 score corresponding to random state:  85 is:  0.8089089890446063
# r2 score corresponding to random state:  86 is:  0.8445935742789037
# r2 score corresponding to random state:  87 is:  0.8025925268292964
# r2 score corresponding to random state:  88 is:  0.7924039063841534
# r2 score corresponding to random state:  89 is:  0.791206452915761
# r2 score corresponding to random state:  90 is:  0.8385739315481447
# r2 score corresponding to random state:  91 is:  0.8185566950148708
# r2 score corresponding to random state:  92 is:  0.8524659716222561
# r2 score corresponding to random state:  93 is:  0.8327154531186864
# r2 score corresponding to random state:  94 is:  0.8756369794203795
# r2 score corresponding to random state:  95 is:  0.7651561600537483
# r2 score corresponding to random state:  96 is:  0.7773669831818676
# r2 score corresponding to random state:  97 is:  0.7878176657890705
# r2 score corresponding to random state:  98 is:  0.7797412459785029
# r2 score corresponding to random state:  99 is:  0.7681734784610612
# max r2 score corresponding to 94  is  0.8756369794203795

# %%
print("Mean r2score for Lasso Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Lasso Regression: ",cross_val_score(lsreg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for Lasso Regression:  0.5989515287247317
# Standard deviation in r2 score for Lasso Regression:  0.2454235123816298

# %%
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
ggbr = GridSearchCV(gbr, parameters, cv=5)
ggbr.fit(x,y)
ggbr.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 1000}

# %%
gbr=GradientBoostingRegressor(learning_rate=0.01,n_estimators=1000)
print("Mean r2score for gradient boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Gradient Boosting Regression: ",cross_val_score(gbr,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for gradient boosting Regression:  0.7641594061300915
# Standard deviation in r2 score for Gradient Boosting Regression:  0.1752630944371944

# %%
r_state=maxr2_score(gbr,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.86554694998323
# r2 score corresponding to random state:  43 is:  0.8452283968696452
# r2 score corresponding to random state:  44 is:  0.861144890236075
# r2 score corresponding to random state:  45 is:  0.8166395924472905
# r2 score corresponding to random state:  46 is:  0.8459002034828706
# r2 score corresponding to random state:  47 is:  0.8148432056870926
# r2 score corresponding to random state:  48 is:  0.8309604809427458
# r2 score corresponding to random state:  49 is:  0.9128541007539505
# r2 score corresponding to random state:  50 is:  0.8216061245901831
# r2 score corresponding to random state:  51 is:  0.8936425688923627
# r2 score corresponding to random state:  52 is:  0.8890903182118147
# r2 score corresponding to random state:  53 is:  0.9058829264550808
# r2 score corresponding to random state:  54 is:  0.8740794191371863
# r2 score corresponding to random state:  55 is:  0.9060824316374378
# r2 score corresponding to random state:  56 is:  0.8946698261816857
# r2 score corresponding to random state:  57 is:  0.8358954846302731
# r2 score corresponding to random state:  58 is:  0.8948596313390671
# r2 score corresponding to random state:  59 is:  0.8351302001748224
# r2 score corresponding to random state:  60 is:  0.8627747525986146
# r2 score corresponding to random state:  61 is:  0.8879144264581208
# r2 score corresponding to random state:  62 is:  0.8629029774194321
# r2 score corresponding to random state:  63 is:  0.8792549556660142
# r2 score corresponding to random state:  64 is:  0.8941791918006321
# r2 score corresponding to random state:  65 is:  0.8545762009920094
# r2 score corresponding to random state:  66 is:  0.8555612216928368
# r2 score corresponding to random state:  67 is:  0.7667831649436339
# r2 score corresponding to random state:  68 is:  0.8104127390310892
# r2 score corresponding to random state:  69 is:  0.893376088864426
# r2 score corresponding to random state:  70 is:  0.8838054173416279
# r2 score corresponding to random state:  71 is:  0.8562000292451
# r2 score corresponding to random state:  72 is:  0.9088061192547698
# r2 score corresponding to random state:  73 is:  0.8823757272801579
# r2 score corresponding to random state:  74 is:  0.8440398128025272
# r2 score corresponding to random state:  75 is:  0.8376714906921283
# r2 score corresponding to random state:  76 is:  0.8769309106109533
# r2 score corresponding to random state:  77 is:  0.8499461731312448
# r2 score corresponding to random state:  78 is:  0.874125363915607
# r2 score corresponding to random state:  79 is:  0.896274526575742
# r2 score corresponding to random state:  80 is:  0.7933651138137656
# r2 score corresponding to random state:  81 is:  0.8750826525222484
# r2 score corresponding to random state:  82 is:  0.8563756952912602
# r2 score corresponding to random state:  83 is:  0.8685469354685229
# r2 score corresponding to random state:  84 is:  0.9070584778034182
# r2 score corresponding to random state:  85 is:  0.8466138986757521
# r2 score corresponding to random state:  86 is:  0.886331476450695
# r2 score corresponding to random state:  87 is:  0.8582521646797296
# r2 score corresponding to random state:  88 is:  0.8256086963629818
# r2 score corresponding to random state:  89 is:  0.8201806596828264
# r2 score corresponding to random state:  90 is:  0.9096676074037793
# r2 score corresponding to random state:  91 is:  0.8559751888250559
# r2 score corresponding to random state:  92 is:  0.8859174749258563
# r2 score corresponding to random state:  93 is:  0.8605771378680431
# r2 score corresponding to random state:  94 is:  0.9202801751635217
# r2 score corresponding to random state:  95 is:  0.8225375385530478
# r2 score corresponding to random state:  96 is:  0.810015528613262
# r2 score corresponding to random state:  97 is:  0.8420144441000901
# r2 score corresponding to random state:  98 is:  0.8481765724146114
# r2 score corresponding to random state:  99 is:  0.8574925993227537
# max r2 score corresponding to 94  is  0.9202801751635217

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[lreg,lsreg,DecisionTreeRegressor()]}
gada = GridSearchCV(ada_reg, parameters, cv=5)
gada.fit(x,y)
gada.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        presort=False, random_state=None, splitter='best'),
#  'learning_rate': 0.1,
#  'n_estimators': 100}

# %%
ada_reg=AdaBoostRegressor(learning_rate=0.1,n_estimators=100)
print("Mean r2score for Ada boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Ada Boosting Regression: ",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2score for Ada boosting Regression:  0.6689354008229093
# Standard deviation in r2 score for Ada Boosting Regression:  0.26719477884306864

# %%
r_state=maxr2_score(ada_reg,x,y)
# Out:
# r2 score corresponding to random state:  42 is:  0.8643065033134306
# r2 score corresponding to random state:  43 is:  0.7734606590921534
# r2 score corresponding to random state:  44 is:  0.7956106971197382
# r2 score corresponding to random state:  45 is:  0.7950938606202341
# r2 score corresponding to random state:  46 is:  0.7977366279008749
# r2 score corresponding to random state:  47 is:  0.8021954322902715
# r2 score corresponding to random state:  48 is:  0.8420286472028565
# r2 score corresponding to random state:  49 is:  0.8487238899131273
# r2 score corresponding to random state:  50 is:  0.7802807410009333
# r2 score corresponding to random state:  51 is:  0.8649715327129132
# r2 score corresponding to random state:  52 is:  0.8555413825785972
# r2 score corresponding to random state:  53 is:  0.8502410552193713
# r2 score corresponding to random state:  54 is:  0.8465030965044944
# r2 score corresponding to random state:  55 is:  0.8568168251292607
# r2 score corresponding to random state:  56 is:  0.879366063213405
# r2 score corresponding to random state:  57 is:  0.7938252426243928
# r2 score corresponding to random state:  58 is:  0.8904727625139454
# r2 score corresponding to random state:  59 is:  0.8091904930733089
# r2 score corresponding to random state:  60 is:  0.8081718195422378
# r2 score corresponding to random state:  61 is:  0.869238622952078
# r2 score corresponding to random state:  62 is:  0.7996645152718419
# r2 score corresponding to random state:  63 is:  0.8604677939526538
# r2 score corresponding to random state:  64 is:  0.8555268321600962
# r2 score corresponding to random state:  65 is:  0.8210584283250398
# r2 score corresponding to random state:  66 is:  0.8113000859232447
# r2 score corresponding to random state:  67 is:  0.7682816131144622
# r2 score corresponding to random state:  68 is:  0.7932701726190693
# r2 score corresponding to random state:  69 is:  0.8793858101099199
# r2 score corresponding to random state:  70 is:  0.8386602781540974
# r2 score corresponding to random state:  71 is:  0.8174370832243287
# r2 score corresponding to random state:  72 is:  0.8778824964822521
# r2 score corresponding to random state:  73 is:  0.8428816587412324
# r2 score corresponding to random state:  74 is:  0.8395484601276781
# r2 score corresponding to random state:  75 is:  0.8146875731759792
# r2 score corresponding to random state:  76 is:  0.8485133990281617
# r2 score corresponding to random state:  77 is:  0.8525752089580875
# r2 score corresponding to random state:  78 is:  0.8591012976932135
# r2 score corresponding to random state:  79 is:  0.8508985336240965
# r2 score corresponding to random state:  80 is:  0.7884987377052582
# r2 score corresponding to random state:  81 is:  0.842926002874242
# r2 score corresponding to random state:  82 is:  0.8154143645843125
# r2 score corresponding to random state:  83 is:  0.8300601680306029
# r2 score corresponding to random state:  84 is:  0.8291563221245892
# r2 score corresponding to random state:  85 is:  0.8252548626642555
# r2 score corresponding to random state:  86 is:  0.8598729447415122
# r2 score corresponding to random state:  87 is:  0.8283931489677502
# r2 score corresponding to random state:  88 is:  0.8146560551639037
# r2 score corresponding to random state:  89 is:  0.7801427799548546
# r2 score corresponding to random state:  90 is:  0.884926686150699
# r2 score corresponding to random state:  91 is:  0.8401627614371864
# r2 score corresponding to random state:  92 is:  0.8697506652806622
# r2 score corresponding to random state:  93 is:  0.8546251186229261
# r2 score corresponding to random state:  94 is:  0.8836562963492758
# r2 score corresponding to random state:  95 is:  0.7832591328848915
# r2 score corresponding to random state:  96 is:  0.7975514416317253
# r2 score corresponding to random state:  97 is:  0.827446149108917
# r2 score corresponding to random state:  98 is:  0.8597844025519965
# r2 score corresponding to random state:  99 is:  0.8071237378653671
# max r2 score corresponding to 58  is  0.8904727625139454

# %% [markdown]
# # Model Selection

# %% [raw]
# I choose GradientBoostingRegressor Model as my preferred model as it performs better on the above dataset.
